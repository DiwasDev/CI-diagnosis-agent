# %%
import polars as pl

# 1. Read the Parquet file
data_path = "/home/divas/ml/CI-diagnosis-agent/data/ci_repair_bench_disambiguated.parquet"
df = pl.read_parquet(data_path)

# 2. View column names
df["primary_hidden_state"].value_counts(normalize=True)['proportion'].sum()
# Out:
# 0.9999999999999999
