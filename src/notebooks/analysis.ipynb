# %%
import json

# %%
data_path = "/home/divas/ml/CI-diagnosis-agent/data/selected_java_failed_job_information.json"

# %%
with open(data_path, "r", encoding="utf-8") as f:
    print(f.read(2000))  # Prints only the first 500 characters
# Out:
# [{"project_name": "xnio/xnio", "run_id": 6421532405, "job_id": 17436162334, "job_name": "api-hotspot-11-windows-latest", "workflow_name": "XNIO CI", "url": "https://github.com/xnio/xnio/actions/runs/6421532405/job/17436162334", "step": "Run Tests", "time": "2023-10-05T16:04:17Z", "labels": ["windows-latest"]}, {"project_name": "xnio/xnio", "run_id": 6108886236, "job_id": 16578853783, "job_name": "nio-impl-hotspot-8-macos-latest", "workflow_name": "XNIO CI", "url": "https://github.com/xnio/xnio/actions/runs/6108886236/job/16578853783", "step": "Run Tests", "time": "2023-09-07T11:05:49Z", "labels": ["macos-latest"]}, {"project_name": "xnio/xnio", "run_id": 6108886236, "job_id": 16578852225, "job_name": "api-hotspot-11-windows-latest", "workflow_name": "XNIO CI", "url": "https://github.com/xnio/xnio/actions/runs/6108886236/job/16578852225", "step": "Run Tests", "time": "2023-09-07T11:05:45Z", "labels": ["windows-latest"]}, {"project_name": "xnio/xnio", "run_id": 6109428600, "job_id": 16
# ...
